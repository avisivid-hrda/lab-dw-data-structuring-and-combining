# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %% [markdown]
# ## Loading the cleaned df from the previous exercise:

# %%
import pandas as pd

df_1 = pd.read_csv("/Users/lee/Documents/GitHub/lab-dw-data-cleaning-and-formatting/cleaned_data.csv")
df_1.head(10)
# Out:
#   Customer id       State Gender             Education  \
# 0     QZ44356     Arizona      F              Bachelor
# 1     AI49188      Nevada      F              Bachelor
# 2     WW63253  California      M              Bachelor
# 3     GA49547  Washington      M  High School or Below
# 4     OC83172      Oregon      F              Bachelor
# 5     XZ87318      Oregon      F               College
# 6     CF85061     Arizona      M                Master
# 7     DY87989      Oregon      M              Bachelor
# 8     BQ94931      Oregon      F               College
# 9     SX51350  California      M               College
#
#    Customer_Lifetime_Value   Income  Monthly_Premium_Auto  \
# 0                697953.59      0.0                  94.0
# 1               1288743.17  48767.0                 108.0
# 2                764586.18      0.0                 106.0
# 3                536307.65  36357.0                  68.0
# 4                825629.78  62902.0                  69.0
# ...

# %% [markdown]
# ## Loading the new dataframes for this exercise:

# %%
df_2 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv")
df_2.head(10)
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
# 5  WL99637     Arizona      M  Bachelor              761413.80%   27293
# 6  UC84059  California      F    Master              689845.53%   70950
# 7  HW62747      Oregon      M   College              229837.92%       0
# 8  BH11344      Oregon      F    Doctor              280669.61%   37009
# 9  TX28465      Nevada      M   College              520611.82%   52629
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00          633.600000
# ...

# %%
df_3 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv")
df_3.head(10)
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
# 5  VI78454     Arizona              2750.705045               College      M
# 6  FP59138      Oregon             13024.130120                Master      M
# 7  XN62489      Oregon              2538.626320              Bachelor      M
# 8  GP66031  California              2585.955652               College      F
# 9  IX68587      Nevada              5096.673223                Master      F
#
#    Income  Monthly Premium Auto  Number of Open Complaints     Policy Type  \
# ...

# %% [markdown]
# ## Cleaning the new dataframes:

# %%
df_2.columns = df_2.columns.str.replace(" ", "_")
df_3.columns = df_3.columns.str.replace(" ", "_")

# %%
df_2= df_2.rename(columns={"Customer": "Customer id", "ST": "State", "GENDER": "Gender"})
df_3= df_3.rename(columns={"Customer": "Customer id"})

# %%
df_2["Gender"].value_counts()
# Out:
# Gender
# F         527
# M         461
# female      2
# Male        1
# Name: count, dtype: int64

# %%
df_2["Gender"] = df_2["Gender"].replace({"female": "F", "Male": "M"})

# %%
df_2["Gender"].value_counts()
# Out:
# Gender
# F    529
# M    462
# Name: count, dtype: int64

# %%
df_3["Gender"].value_counts()
# Out:
# Gender
# F    3576
# M    3494
# Name: count, dtype: int64

# %%
df_2["State"].value_counts()
# Out:
# State
# Oregon        303
# California    277
# Arizona       142
# Nevada        125
# Washington    100
# AZ             49
# Name: count, dtype: int64

# %%
df_2["State"] = df_2["State"].replace({"AZ": "Arizona"})

# %%
df_2["State"].value_counts()
# Out:
# State
# Oregon        303
# California    277
# Arizona       191
# Nevada        125
# Washington    100
# Name: count, dtype: int64

# %%
df_3["State"].value_counts()
# Out:
# State
# California    2544
# Oregon        1978
# Arizona       1302
# Nevada         659
# Washington     587
# Name: count, dtype: int64

# %%
df_2["Education"].value_counts()
# Out:
# Education
# College                 311
# High School or Below    290
# Bachelor                243
# Master                   86
# Doctor                   49
# Bachelors                17
# Name: count, dtype: int64

# %%
df_2["Education"] = df_2["Education"].replace({"Bachelors": "Bachelor"})

# %%
df_2["Education"].value_counts()
# Out:
# Education
# College                 311
# High School or Below    290
# Bachelor                260
# Master                   86
# Doctor                   49
# Name: count, dtype: int64

# %%
df_3["Education"].value_counts()
# Out:
# Education
# Bachelor                2152
# College                 2058
# High School or Below    2030
# Master                   572
# Doctor                   258
# Name: count, dtype: int64

# %%
df_2["Customer_Lifetime_Value"].value_counts()
# Out:
# Customer_Lifetime_Value
# 552821.28%     4
# 600521.48%     3
# 538949.95%     3
# 1203662.05%    3
# 871704.98%     3
#               ..
# 728503.10%     1
# 1765196.34%    1
# 1702989.34%    1
# 403931.50%     1
# 399258.39%     1
# Name: count, Length: 950, dtype: int64

# %%
df_2["Customer_Lifetime_Value"] = df_2["Customer_Lifetime_Value"].str.rstrip("%")

# %%
df_3["Customer_Lifetime_Value"].value_counts()
# Out:
# Customer_Lifetime_Value
# 2647.519741     6
# 2659.705650     6
# 4686.469674     6
# 4270.034394     6
# 13727.799720    6
#                ..
# 11281.524510    1
# 8759.592518     1
# 4928.001408     1
# 4896.261605     1
# 2611.836866     1
# Name: count, Length: 6288, dtype: int64

# %%
df_2["Vehicle_Class"].value_counts()
# Out:
# Vehicle_Class
# Four-Door Car    519
# Two-Door Car     211
# SUV              174
# Sports Car        55
# Luxury SUV        21
# Luxury Car        16
# Name: count, dtype: int64

# %%
df_2["Vehicle_Class"] = df_2["Vehicle_Class"].replace({"Sports Car": "Luxury", "Luxury SUV": "Luxury", "Luxury Car": "Luxury"})

# %%
df_2["Vehicle_Class"].value_counts()
# Out:
# Vehicle_Class
# Four-Door Car    519
# Two-Door Car     211
# SUV              174
# Luxury            92
# Name: count, dtype: int64

# %%
df_3["Vehicle_Class"].value_counts()
# Out:
# Vehicle_Class
# Four-Door Car    3546
# Two-Door Car     1480
# SUV              1401
# Sports Car        371
# Luxury SUV        141
# Luxury Car        131
# Name: count, dtype: int64

# %%
df_3["Vehicle_Class"] = df_3["Vehicle_Class"].replace({"Sports Car": "Luxury", "Luxury SUV": "Luxury", "Luxury Car": "Luxury"})

# %%
df_3["Vehicle_Class"].value_counts()
# Out:
# Vehicle_Class
# Four-Door Car    3546
# Two-Door Car     1480
# SUV              1401
# Luxury            643
# Name: count, dtype: int64

# %%
df_2["Number_of_Open_Complaints"] = df_2["Number_of_Open_Complaints"].str.split("/").str[1]

# %% [markdown]
# ## Loading the cleaned dataframes

# %%
df_1.head()
# Out:
#   Customer id       State Gender             Education  \
# 0     QZ44356     Arizona      F              Bachelor
# 1     AI49188      Nevada      F              Bachelor
# 2     WW63253  California      M              Bachelor
# 3     GA49547  Washington      M  High School or Below
# 4     OC83172      Oregon      F              Bachelor
#
#    Customer_Lifetime_Value   Income  Monthly_Premium_Auto  \
# 0                697953.59      0.0                  94.0
# 1               1288743.17  48767.0                 108.0
# 2                764586.18      0.0                 106.0
# 3                536307.65  36357.0                  68.0
# 4                825629.78  62902.0                  69.0
#
#    Number_of_Open_Complaints     Policy_Type  Vehicle_Class  \
# 0                        NaN   Personal Auto  Four-Door Car
# 1                        NaN   Personal Auto   Two-Door Car
# 2                        NaN  Corporate Auto            SUV
# ...

# %%
df_2.head()
# Out:
#   Customer id       State Gender Education Customer_Lifetime_Value  Income  \
# 0     GS98873     Arizona      F  Bachelor               323912.47   16061
# 1     CW49887  California      F    Master               462680.11   79487
# 2     MY31220  California      F   College               899704.02   54230
# 3     UH35128      Oregon      F   College              2580706.30   71210
# 4     WH52799     Arizona      F   College               380812.21   94903
#
#    Monthly_Premium_Auto Number_of_Open_Complaints  Total_Claim_Amount  \
# 0                    88                         0               633.6
# 1                   114                         0               547.2
# 2                   112                         0               537.6
# 3                   214                         1              1027.2
# 4                    94                         0               451.2
#
#       Policy_Type  Vehicle_Class
# 0   Personal Auto  Four-Door Car
# ...

# %%
df_3.head()
# Out:
#   Customer id       State  Customer_Lifetime_Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
#
#   Gender  Income  Monthly_Premium_Auto  Number_of_Open_Complaints  \
# 0      M       0                   104                          0
# 1      M       0                    66                          0
# 2      F   25820                    82                          0
# 3      F       0                   121                          0
# 4      M   30366                   101                          2
#
#      Policy_Type  Total_Claim_Amount  Vehicle_Class
# 0  Personal Auto          499.200000   Two-Door Car
# ...

# %% [markdown]
# ## Concatenating the datasets

# %%
df_all = pd.concat([df_1, df_2, df_3], ignore_index=True)

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv")
df.head()
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  ...  \
# 0     Basic   College        2011-02-18         Employed      M  ...
# 1     Basic   College        2011-01-18       Unemployed      F  ...
# 2     Basic  Bachelor        2011-02-10         Employed      M  ...
# 3  Extended   College        2011-01-11         Employed      M  ...
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    number_of_policies     policy_type        policy  renew_offer_type  \
# ...

# %%
df.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size', 'vehicle_type', 'month'],
#       dtype='object')

# %% [markdown]
# ## Cleaning the Dataset

# %%
df = df.drop(columns=["unnamed:_0"])

# %%
df["vehicle_class"].value_counts()
# Out:
# vehicle_class
# Four-Door Car    5834
# Two-Door Car     2118
# SUV              2012
# Sports Car        550
# Luxury SUV        208
# Luxury Car        188
# Name: count, dtype: int64

# %%
df["vehicle_class"] = df["vehicle_class"].replace({"Sports Car": "Luxury Car","Luxury SUV": "Luxury Car"})

# %%
df["vehicle_size"].value_counts()
# Out:
# vehicle_size
# Medsize    7873
# Small      1966
# Large      1071
# Name: count, dtype: int64

# %%
df["vehicle_size"] = df["vehicle_size"].replace({"Medsize": "Medium"})

# %% [markdown]
# ## Exploration and Analysis

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
pivot_1 = df.pivot_table(
    values = "monthly_premium_auto", #what should be calculated (as sum, count)
    index = "sales_channel", #with reference to which parameter
    aggfunc = "sum" #since total revenue is asked, sum is used
).round(2)

pivot_1
# Out:
#                monthly_premium_auto
# sales_channel
# Agent                        386335
# Branch                       280953
# Call Center                  197970
# Web                          151511

# %% [markdown]
# Insights:
# - Marketing through 'agents' has fetched the most revenue. This could be an indicator that personal contact works the best with the customers.
# - Call Center is also targeted to contact customers regarding the products, but it is only the third most revenue generating. This could mean that the 'call center' personnel could use some training from the 'agents' on how to bring more customers, how to market different products successfully.
# - Web channel is the least revenue generating. So paid marketing team's efforts should be reformed and mesaured. Or it could mean that most of our customers / target customers do not use web enough for us to attract them through the channel, i.e., could be seniors / not so tech savvy group.

# %%
pivot_2 = df.pivot_table(
    values = "customer_lifetime_value", #what should be calculated (as sum, count)
    index = "gender", #with reference to which parameter
    aggfunc = "mean" #since average CLV is asked, mean is used
).round(2)
pivot_2
# Out:
#         customer_lifetime_value
# gender
# F                       8071.11
# M                       7963.04

# %%
df["gender"].value_counts()
# Out:
# gender
# F    5573
# M    5337
# Name: count, dtype: int64

# %% [markdown]
# Insights:
# - Female customers have an avg CLV of 8k, which is more or less equal to that of the male customer CLV. It could mean that targeting a single gender for marketing would not make much difference. This is also due to the fact that the number of male and female customers are almost the same.
# - Since they both generate around the same CLV, the pricing team may also use this data to price their policies /premiums similarly.

# %%
pivot_2 = df.pivot_table(
    values = "customer_lifetime_value", #what should be calculated (as sum, count)
    index = "education", #with reference to which parameter
    aggfunc = "mean" #since average CLV is asked, mean is used
).round(2)
pivot_2
# Out:
#                       customer_lifetime_value
# education
# Bachelor                              7792.27
# College                               7900.07
# Doctor                                7372.03
# High School or Below                  8415.29
# Master                                8162.52

# %%
df["education"].value_counts()
# Out:
# education
# Bachelor                3272
# College                 3204
# High School or Below    3146
# Master                   887
# Doctor                   401
# Name: count, dtype: int64

# %% [markdown]
# Insights:
# - Customers who have an education of high school or below have the highest CLV, followed by Masters holders.
# - The least CLV holders are the customers with doctorates.
# - Does a higher education level mean they know / learn how to use their insurance policies / companies to their maximum benefit? Since Masters holders also have a relatively low CLV, this might not hold good for this theory overall, but interesting perspective to look into.

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
df["number_of_open_complaints"].value_counts()
# Out:
# number_of_open_complaints
# 0.000000    8160
# 1.000000    1145
# 0.384256     633
# 2.000000     414
# 3.000000     324
# 4.000000     166
# 5.000000      68
# Name: count, dtype: int64

# %%
complaints = (
    df.groupby(["policy_type", "month"])["number_of_open_complaints"]
    .sum()
    .reset_index()
    .round()
)

# %%
print(complaints) #display the above as a long format table
# Out:
#       policy_type  month  number_of_open_complaints
# 0  Corporate Auto      1                      443.0
# 1  Corporate Auto      2                      385.0
# 2   Personal Auto      1                     1728.0
# 3   Personal Auto      2                     1454.0
# 4    Special Auto      1                       87.0
# 5    Special Auto      2                       95.0

# %%
pivot = df.pivot_table(
    values = "number_of_open_complaints",
    index = "month",
    aggfunc= "sum"
).round()
pivot
# Out:
#        number_of_open_complaints
# month
# 1                         2258.0
# 2                         1934.0

# %% [markdown]
# Insights:
# - The month January and February saw the most number of open complaints.
# - Month January saw the most number of open complaints, followed by February.
# - This could mean that there is an overlag from the staff due to December holidays, so complaints were carried forward to the following two months for actioning.
# - It could also mean that there are more customer complaints at the beginning of the year because customers realise and focus on the policies / investments they hold during that time and want to get their issues resolved.
